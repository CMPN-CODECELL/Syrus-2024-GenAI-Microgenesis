# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ----------
# absl-py                       1.4.0
# ail-typo-squatting            2.4.3
# aiohttp                       3.8.4
# aiosignal                     1.3.1
# anyio                         3.6.2
# asttokens                     2.2.1
# astunparse                    1.6.3
# async-timeout                 4.0.2
# attrs                         22.2.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# beautifulsoup4                4.11.2
# black                         23.1.0
# blis                          0.7.7
# Bottleneck                    1.3.5
# brotlipy                      0.7.0
# bs4                           0.0.1
# CacheControl                  0.13.1
# cachetools                    5.3.0
# catalogue                     2.0.7
# certifi                       2024.2.2
# cffi                          1.15.1
# charset-normalizer            2.0.4
# ...

# %%
import numpy as np
import cv2
